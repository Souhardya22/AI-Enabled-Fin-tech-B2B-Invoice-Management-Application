# %%
#importing genral libraries required
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#read dataset from csv file and displaying the dataset
data = pd.read_csv(r"C:\Users\KIIT\Desktop\Highradius Internship Training\Project\dataset.csv")
data
# Out:
#       business_code cust_number       name_customer           clear_date  \
# 0              U001  0200769623        WAL-MAR corp  2020-02-11 00:00:00
# 1              U001  0200980828              BEN E   2019-08-08 00:00:00
# 2              U001  0200792734          MDV/ trust  2019-12-30 00:00:00
# 3              CA02  0140105686            SYSC llc                  NaN
# 4              U001  0200769623  WAL-MAR foundation  2019-11-25 00:00:00
# ...             ...         ...                 ...                  ...
# 49995          U001  0200561861      CO corporation                  NaN
# 49996          U001  0200769623          WAL-MAR co  2019-09-03 00:00:00
# 49997          U001  0200772595    SAFEW associates  2020-03-05 00:00:00
# 49998          U001  0200726979           BJ'S  llc  2019-12-12 00:00:00
# 49999          U001  0200020431            DEC corp  2019-01-15 00:00:00
#
#        buisness_year        doc_id posting_date  document_create_date  \
# ...

# %%
data['baseline_create_date'].equals(data['document_create_date'])
# Out:
# False

# %%
#selecting first 5 rows for normal checking
data.head()
# Out:
#   business_code cust_number       name_customer           clear_date  \
# 0          U001  0200769623        WAL-MAR corp  2020-02-11 00:00:00
# 1          U001  0200980828              BEN E   2019-08-08 00:00:00
# 2          U001  0200792734          MDV/ trust  2019-12-30 00:00:00
# 3          CA02  0140105686            SYSC llc                  NaN
# 4          U001  0200769623  WAL-MAR foundation  2019-11-25 00:00:00
#
#    buisness_year        doc_id posting_date  document_create_date  \
# 0         2020.0  1.930438e+09   2020-01-26              20200125
# 1         2019.0  1.929646e+09   2019-07-22              20190722
# 2         2019.0  1.929874e+09   2019-09-14              20190914
# 3         2020.0  2.960623e+09   2020-03-30              20200330
# 4         2019.0  1.930148e+09   2019-11-13              20191113
#
#    document_create_date.1  due_in_date invoice_currency document type  \
# 0                20200126   20200210.0              USD            RV
# ...

# %%
#showing number of rows and columns (number of rows, number of columns)
data.shape
# Out:
# (50000, 19)

# %%
#showing name of the columns' heads
data.columns
# Out:
# Index(['business_code', 'cust_number', 'name_customer', 'clear_date',
#        'buisness_year', 'doc_id', 'posting_date', 'document_create_date',
#        'document_create_date.1', 'due_in_date', 'invoice_currency',
#        'document type', 'posting_id', 'area_business', 'total_open_amount',
#        'baseline_create_date', 'cust_payment_terms', 'invoice_id', 'isOpen'],
#       dtype='object')

# %%
#finding number of rows using length
rows = len(data.axes[0])
rows
# Out:
# 50000

# %%
#details of data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           50000 non-null  object
#  1   cust_number             50000 non-null  object
#  2   name_customer           50000 non-null  object
#  3   clear_date              40000 non-null  object
#  4   buisness_year           50000 non-null  float64
#  5   doc_id                  50000 non-null  float64
#  6   posting_date            50000 non-null  object
#  7   document_create_date    50000 non-null  int64
#  8   document_create_date.1  50000 non-null  int64
#  9   due_in_date             50000 non-null  float64
#  10  invoice_currency        50000 non-null  object
#  11  document type           50000 non-null  object
#  12  posting_id              50000 non-null  float64
#  13  area_business           0 non-null      float64
# ...

# %%
data['buisness_year'] = data['buisness_year'].astype(int)

# %%
#displaying only the date columns
data[['clear_date', 'posting_date', 'document_create_date', 'document_create_date.1', 'due_in_date', 'baseline_create_date']]
# Out:
#                 clear_date posting_date  document_create_date  \
# 0      2020-02-11 00:00:00   2020-01-26              20200125
# 1      2019-08-08 00:00:00   2019-07-22              20190722
# 2      2019-12-30 00:00:00   2019-09-14              20190914
# 3                      NaN   2020-03-30              20200330
# 4      2019-11-25 00:00:00   2019-11-13              20191113
# ...                    ...          ...                   ...
# 49995                  NaN   2020-04-21              20200417
# 49996  2019-09-03 00:00:00   2019-08-15              20190814
# 49997  2020-03-05 00:00:00   2020-02-19              20200218
# 49998  2019-12-12 00:00:00   2019-11-27              20191126
# 49999  2019-01-15 00:00:00   2019-01-05              20190105
#
#        document_create_date.1  due_in_date  baseline_create_date
# 0                    20200126   20200210.0            20200126.0
# 1                    20190722   20190811.0            20190722.0
# ...

# %%
#converting object,integer and float values into date format
data['clear_date'] = pd.to_datetime(data['clear_date'], format = '%Y%m%d', infer_datetime_format=True)
data['posting_date'] = pd.to_datetime(data['posting_date'], format = '%Y%m%d', infer_datetime_format=True)
data['document_create_date'] = pd.to_datetime(data['document_create_date'], format = '%Y%m%d', infer_datetime_format=True)
data['document_create_date.1'] = pd.to_datetime(data['document_create_date.1'], format = '%Y%m%d', infer_datetime_format=True)
data['due_in_date'] = pd.to_datetime(data['due_in_date'], format = '%Y%m%d', infer_datetime_format=True)
data['baseline_create_date'] = pd.to_datetime(data['baseline_create_date'], format = '%Y%m%d', infer_datetime_format=True)

# %%
#checking these columns if they are correctly converted
data[['clear_date', 'posting_date', 'document_create_date', 'document_create_date.1', 'due_in_date', 'baseline_create_date']]
# Out:
#       clear_date posting_date document_create_date document_create_date.1  \
# 0     2020-02-11   2020-01-26           2020-01-25             2020-01-26
# 1     2019-08-08   2019-07-22           2019-07-22             2019-07-22
# 2     2019-12-30   2019-09-14           2019-09-14             2019-09-14
# 3            NaT   2020-03-30           2020-03-30             2020-03-30
# 4     2019-11-25   2019-11-13           2019-11-13             2019-11-13
# ...          ...          ...                  ...                    ...
# 49995        NaT   2020-04-21           2020-04-17             2020-04-21
# 49996 2019-09-03   2019-08-15           2019-08-14             2019-08-15
# 49997 2020-03-05   2020-02-19           2020-02-18             2020-02-19
# 49998 2019-12-12   2019-11-27           2019-11-26             2019-11-27
# 49999 2019-01-15   2019-01-05           2019-01-05             2019-01-05
#
#       due_in_date baseline_create_date
# 0      2020-02-10           2020-01-26
# ...

# %%
#describing data
data.describe()
# Out:
#        buisness_year        doc_id  posting_id  area_business  \
# count   50000.000000  5.000000e+04     50000.0            0.0
# mean     2019.305700  2.012238e+09         1.0            NaN
# std         0.460708  2.885235e+08         0.0            NaN
# min      2019.000000  1.928502e+09         1.0            NaN
# 25%      2019.000000  1.929342e+09         1.0            NaN
# 50%      2019.000000  1.929964e+09         1.0            NaN
# 75%      2020.000000  1.930619e+09         1.0            NaN
# max      2020.000000  9.500000e+09         1.0            NaN
#
#        total_open_amount    invoice_id        isOpen
# count       50000.000000  4.999400e+04  50000.000000
# mean        32337.021651  2.011340e+09      0.200000
# std         39205.975231  2.766335e+08      0.400004
# min             0.720000  1.928502e+09      0.000000
# 25%          4928.312500  1.929342e+09      0.000000
# 50%         17609.010000  1.929964e+09      0.000000
# ...

# %%
#checking if there any null values present or not(total = number of null values present in each column, percent = percentage of null values present)
total = data.isnull().sum().sort_values(ascending=False)
percent = (data.isnull().mean()*100).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data
# Out:
#                         Total  Percent
# area_business           50000  100.000
# clear_date              10000   20.000
# invoice_id                  6    0.012
# business_code               0    0.000
# invoice_currency            0    0.000
# cust_payment_terms          0    0.000
# baseline_create_date        0    0.000
# total_open_amount           0    0.000
# posting_id                  0    0.000
# document type               0    0.000
# due_in_date                 0    0.000
# cust_number                 0    0.000
# document_create_date.1      0    0.000
# document_create_date        0    0.000
# posting_date                0    0.000
# doc_id                      0    0.000
# buisness_year               0    0.000
# name_customer               0    0.000
# isOpen                      0    0.000

# %%
#checking proportion of NaN values using seaborn library
sns.heatmap(data.isnull(), cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
#storing the dropping columns into another dataframe
drop_datas = pd.DataFrame()
drop_datas['area_business'] = data['area_business']
#dropping null column
data.drop(columns='area_business', inplace=True)
data.head()
# Out:
#   business_code cust_number       name_customer clear_date  buisness_year  \
# 0          U001  0200769623        WAL-MAR corp 2020-02-11           2020
# 1          U001  0200980828              BEN E  2019-08-08           2019
# 2          U001  0200792734          MDV/ trust 2019-12-30           2019
# 3          CA02  0140105686            SYSC llc        NaT           2020
# 4          U001  0200769623  WAL-MAR foundation 2019-11-25           2019
#
#          doc_id posting_date document_create_date document_create_date.1  \
# 0  1.930438e+09   2020-01-26           2020-01-25             2020-01-26
# 1  1.929646e+09   2019-07-22           2019-07-22             2019-07-22
# 2  1.929874e+09   2019-09-14           2019-09-14             2019-09-14
# 3  2.960623e+09   2020-03-30           2020-03-30             2020-03-30
# 4  1.930148e+09   2019-11-13           2019-11-13             2019-11-13
#
#   due_in_date invoice_currency document type  posting_id  total_open_amount  \
# ...

# %%
drop_datas.head()
# Out:
#    area_business
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
data.shape
# Out:
# (50000, 18)

# %%
#checking for duplicated values
duplicate_data = data[data.duplicated()]
#showing duplicated rows
duplicate_data
# Out:
#       business_code cust_number        name_customer clear_date  \
# 1041           U001  0200769623           WAL-MAR in 2019-03-12
# 2400           U001  0200769623        WAL-MAR trust 2019-08-28
# 2584           U001  0200769623  WAL-MAR corporation 2019-12-16
# 3755           U001  0200769623             WAL-MAR  2019-11-22
# 3873           CA02  0140104409       LOB associates        NaT
# ...             ...         ...                  ...        ...
# 49928          U001  0200915438           GROC trust 2019-08-15
# 49963          U001  0200759878                SA us 2019-01-29
# 49986          U001  0200772670  ASSOCIAT foundation 2019-06-12
# 49990          U001  0200765011           MAINES llc 2019-06-06
# 49991          U001  0200704045             RA trust 2019-10-25
#
#        buisness_year        doc_id posting_date document_create_date  \
# 1041            2019  1.928870e+09   2019-02-28           2019-02-27
# ...

# %%
#counting unique values present in each column
count_uniques = data.nunique(axis=0)
count_uniques
# Out:
# business_code                 6
# cust_number                1425
# name_customer              4197
# clear_date                  403
# buisness_year                 2
# doc_id                    48839
# posting_date                506
# document_create_date        507
# document_create_date.1      506
# due_in_date                 547
# invoice_currency              2
# document type                 2
# posting_id                    1
# total_open_amount         44349
# baseline_create_date        506
# cust_payment_terms           74
# invoice_id                48833
# isOpen                        2
# dtype: int64

# %%
#count the number of US Dollar and Canadian Dollar in 'invoice_currency' column
data['invoice_currency'].value_counts()
# Out:
# USD    46081
# CAD     3919
# Name: invoice_currency, dtype: int64

# %%
#converting the 'total_open_amount' from CAD to USD, using 1 CAD = 0.79 USD
data.loc[data['invoice_currency'] == 'CAD', 'total_open_amount'] = 0.79 * data['total_open_amount']
#replacing CAD to USD
data.loc[data['invoice_currency'] == 'CAD', 'invoice_currency'] = 'USD'

# %%
#rounding the amount to two decimal places
data['total_open_amount'] = round(data['total_open_amount'],2)
data
# Out:
#       business_code cust_number       name_customer clear_date  buisness_year  \
# 0              U001  0200769623        WAL-MAR corp 2020-02-11           2020
# 1              U001  0200980828              BEN E  2019-08-08           2019
# 2              U001  0200792734          MDV/ trust 2019-12-30           2019
# 3              CA02  0140105686            SYSC llc        NaT           2020
# 4              U001  0200769623  WAL-MAR foundation 2019-11-25           2019
# ...             ...         ...                 ...        ...            ...
# 49995          U001  0200561861      CO corporation        NaT           2020
# 49996          U001  0200769623          WAL-MAR co 2019-09-03           2019
# 49997          U001  0200772595    SAFEW associates 2020-03-05           2020
# 49998          U001  0200726979           BJ'S  llc 2019-12-12           2019
# 49999          U001  0200020431            DEC corp 2019-01-15           2019
#
# ...

# %%
#install the fast_ml package
# !pip install fast_ml

# %%
#checking the columns with constant and quasi-constant variable
from fast_ml.feature_selection import get_constant_features

constant_features = get_constant_features(data)
constant_features.head()
# Out:
#              Desc               Var Value     Perc
# 0        Constant  invoice_currency   USD  100.000
# 1        Constant        posting_id   1.0  100.000
# 2  Quasi Constant     document type    RV   99.988

# %%
#to get constant_features_list
constant_features_list = constant_features.query("Desc=='Constant'")['Var'].to_list()
constant_features_list
# Out:
# ['invoice_currency', 'posting_id']

# %%
#to get quasi_constant_features_list
quasi_constant_features_list = constant_features.query("Desc=='Quasi Constant'")['Var'].to_list()
quasi_constant_features_list
# Out:
# ['document type']

# %%
drop_datas[['posting_id', 'document type', 'invoice_currency']] = data[['posting_id', 'document type', 'invoice_currency']]
#dropping constant and quasi-constant listed columns
data.drop(columns = constant_features_list, inplace=True)
data.drop(columns = quasi_constant_features_list, inplace=True)

# %%
drop_datas.head()
# Out:
#    area_business  posting_id document type invoice_currency
# 0            NaN         1.0            RV              USD
# 1            NaN         1.0            RV              USD
# 2            NaN         1.0            RV              USD
# 3            NaN         1.0            RV              USD
# 4            NaN         1.0            RV              USD

# %%
data.shape
# Out:
# (50000, 15)

# %%
drop_datas[['business_code', 'cust_number', 'doc_id', 'document_create_date', 'cust_payment_terms', 'invoice_id']] = data[['business_code', 'cust_number', 'doc_id', 'document_create_date', 'cust_payment_terms', 'invoice_id']]
#dropping useless columns as doc_id and invoice_id filled with unique values, buisness_code, cust_number and cust_payment_terms don't required and we have already the normalized version of document_create_date
data.drop(columns=['business_code', 'cust_number', 'doc_id', 'document_create_date', 'cust_payment_terms', 'invoice_id'], inplace=True)
data.head()
# Out:
#         name_customer clear_date  buisness_year posting_date  \
# 0        WAL-MAR corp 2020-02-11           2020   2020-01-26
# 1              BEN E  2019-08-08           2019   2019-07-22
# 2          MDV/ trust 2019-12-30           2019   2019-09-14
# 3            SYSC llc        NaT           2020   2020-03-30
# 4  WAL-MAR foundation 2019-11-25           2019   2019-11-13
#
#   document_create_date.1 due_in_date  total_open_amount baseline_create_date  \
# 0             2020-01-26  2020-02-10           54273.28           2020-01-26
# 1             2019-07-22  2019-08-11           79656.60           2019-07-22
# 2             2019-09-14  2019-09-29            2253.86           2019-09-14
# 3             2020-03-30  2020-04-10            2606.76           2020-03-31
# 4             2019-11-13  2019-11-28           33133.29           2019-11-13
#
#    isOpen
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0

# %%
data.shape
# Out:
# (50000, 9)

# %%
#counting the numbers of unique values present in respective column
data['buisness_year'].value_counts()
# Out:
# 2019    34715
# 2020    15285
# Name: buisness_year, dtype: int64

# %%
data['posting_year'] = pd.DatetimeIndex(data['posting_date']).year
data['posting_year'].value_counts()
# Out:
# 2019    34773
# 2020    15095
# 2018      132
# Name: posting_year, dtype: int64

# %%
data['baseline_create_year'] = pd.DatetimeIndex(data['baseline_create_date']).year
data['baseline_create_year'].value_counts()
# Out:
# 2019    34765
# 2020    15103
# 2018      132
# Name: baseline_create_year, dtype: int64

# %%
data['document_create_year'] = pd.DatetimeIndex(data['document_create_date.1']).year
data['document_create_year'].value_counts()
# Out:
# 2019    34773
# 2020    15095
# 2018      132
# Name: document_create_year, dtype: int64

# %%
#plotting histogram
data[['buisness_year', 'document_create_year', 'posting_year', 'baseline_create_year']].hist(figsize = (20, 15))
# Out:
# array([[<AxesSubplot:title={'center':'buisness_year'}>,
#         <AxesSubplot:title={'center':'document_create_year'}>],
#        [<AxesSubplot:title={'center':'posting_year'}>,
#         <AxesSubplot:title={'center':'baseline_create_year'}>]],
#       dtype=object)

# %%
#counting the same years
(data['buisness_year'] == pd.DatetimeIndex(data['posting_date']).year).sum()
# Out:
# 49678

# %%
(data['buisness_year'] == pd.DatetimeIndex(data['baseline_create_date']).year).sum()
# Out:
# 49686

# %%
(data['buisness_year'] == pd.DatetimeIndex(data['document_create_date.1']).year).sum()
# Out:
# 49678

# %%
#counting the same values
(data['document_create_date.1'] == data['posting_date']).sum()
# Out:
# 49994

# %%
(data['document_create_date.1'] == data['baseline_create_date']).sum()
# Out:
# 44452

# %%
(data['posting_date'] == data['baseline_create_date']).sum()
# Out:
# 44446

# %%
#counting the numbers of document create dates those are exceeding the due date and clear date
(data['document_create_date.1'] >= data['due_in_date']).sum()
# Out:
# 845

# %%
(data['document_create_date.1'] >= data['clear_date']).sum()
# Out:
# 239

# %%
#counting the numbers of baseline create date those are exceeding the due date and clear date
(data['baseline_create_date'] >= data['due_in_date']).sum()
# Out:
# 700

# %%
(data['baseline_create_date'] >= data['clear_date']).sum()
# Out:
# 54

# %%
#calculating the delay of clearing invoices
data['delay'] = data['clear_date'] - data['due_in_date']

# %%
drop_datas[['buisness_year', 'posting_date']] = data[['buisness_year', 'posting_date']] 
#dropping buisness_year as it is similar to other dates' years  and posting_date as it is almost same as document_create_date.1
data.drop(columns=['buisness_year', 'posting_date', 'document_create_year', 'posting_year', 'baseline_create_year'], inplace=True)
data.head()
# Out:
#         name_customer clear_date document_create_date.1 due_in_date  \
# 0        WAL-MAR corp 2020-02-11             2020-01-26  2020-02-10
# 1              BEN E  2019-08-08             2019-07-22  2019-08-11
# 2          MDV/ trust 2019-12-30             2019-09-14  2019-09-29
# 3            SYSC llc        NaT             2020-03-30  2020-04-10
# 4  WAL-MAR foundation 2019-11-25             2019-11-13  2019-11-28
#
#    total_open_amount baseline_create_date  isOpen   delay
# 0           54273.28           2020-01-26       0  1 days
# 1           79656.60           2019-07-22       0 -3 days
# 2            2253.86           2019-09-14       0 92 days
# 3            2606.76           2020-03-31       1     NaT
# 4           33133.29           2019-11-13       0 -3 days

# %%
drop_datas.head()
# Out:
#    area_business  posting_id document type invoice_currency business_code  \
# 0            NaN         1.0            RV              USD          U001
# 1            NaN         1.0            RV              USD          U001
# 2            NaN         1.0            RV              USD          U001
# 3            NaN         1.0            RV              USD          CA02
# 4            NaN         1.0            RV              USD          U001
#
#   cust_number        doc_id document_create_date cust_payment_terms  \
# 0  0200769623  1.930438e+09           2020-01-25               NAH4
# 1  0200980828  1.929646e+09           2019-07-22               NAD1
# 2  0200792734  1.929874e+09           2019-09-14               NAA8
# 3  0140105686  2.960623e+09           2020-03-30               CA10
# 4  0200769623  1.930148e+09           2019-11-13               NAH4
#
#      invoice_id  buisness_year posting_date
# 0  1.930438e+09           2020   2020-01-26
# ...

# %%
data.shape
# Out:
# (50000, 8)

# %%
drop_datas.shape
# Out:
# (50000, 12)

# %%
#sorting in descending order
data['isOpen'].sort_values(ascending = False)
# Out:
# 38809    1
# 7656     1
# 22811    1
# 34764    1
# 22809    1
#         ..
# 18436    0
# 18437    0
# 18438    0
# 18439    0
# 49999    0
# Name: isOpen, Length: 50000, dtype: int64

# %%
#counting the number of unique variables present in this column
data['isOpen'].value_counts()
# Out:
# 0    40000
# 1    10000
# Name: isOpen, dtype: int64

# %%
#dividing into train and test dataset on the basis of 'isopen'
train, test = [x for _, x in data.groupby(data['isOpen'] > 0)]

# %%
#displaying train set
train
# Out:
#             name_customer clear_date document_create_date.1 due_in_date  \
# 0            WAL-MAR corp 2020-02-11             2020-01-26  2020-02-10
# 1                  BEN E  2019-08-08             2019-07-22  2019-08-11
# 2              MDV/ trust 2019-12-30             2019-09-14  2019-09-29
# 4      WAL-MAR foundation 2019-11-25             2019-11-13  2019-11-28
# 5        THE  corporation 2019-12-04             2019-09-20  2019-10-04
# ...                   ...        ...                    ...         ...
# 49994        C&S WH trust 2019-07-25             2019-07-10  2019-07-25
# 49996          WAL-MAR co 2019-09-03             2019-08-15  2019-08-30
# 49997    SAFEW associates 2020-03-05             2020-02-19  2020-03-05
# 49998           BJ'S  llc 2019-12-12             2019-11-27  2019-12-12
# 49999            DEC corp 2019-01-15             2019-01-05  2019-01-24
#
#        total_open_amount baseline_create_date  isOpen   delay
# ...

# %%
test
# Out:
#              name_customer clear_date document_create_date.1 due_in_date  \
# 3                 SYSC llc        NaT             2020-03-30  2020-04-10
# 7                  TARG us        NaT             2020-03-19  2020-04-03
# 10                     AM         NaT             2020-03-11  2020-03-26
# 14              OK systems        NaT             2020-04-15  2020-04-30
# 15        DECA corporation        NaT             2020-04-23  2020-04-26
# ...                    ...        ...                    ...         ...
# 49975           WAL-MAR in        NaT             2020-03-10  2020-03-25
# 49980  WAL-MAR corporation        NaT             2020-05-03  2020-05-18
# 49982             DOLLA co        NaT             2020-03-11  2020-03-26
# 49992             SYSCO co        NaT             2020-03-25  2020-04-09
# 49995       CO corporation        NaT             2020-04-21  2020-05-06
#
#        total_open_amount baseline_create_date  isOpen delay
# ...

# %%
#saving train as csv file
train.to_csv(r"C:\Users\KIIT\Desktop\Highradius Internship Training\Project\train.csv")

# %%
#saving train as csv file
test.to_csv(r"C:\Users\KIIT\Desktop\Highradius Internship Training\Project\test.csv")

# %%
constant_features = get_constant_features(train)
constant_features.head()
# Out:
#        Desc     Var Value   Perc
# 0  Constant  isOpen     0  100.0

# %%
constant_features_list = constant_features.query("Desc=='Constant'")['Var'].to_list()
print(constant_features_list)
# Out:
# ['isOpen']

# %%
train.drop(columns = constant_features_list, inplace=True)
train.shape
# Out:
# (40000, 7)

# %%
train.head()
# Out:
#         name_customer clear_date document_create_date.1 due_in_date  \
# 0        WAL-MAR corp 2020-02-11             2020-01-26  2020-02-10
# 1              BEN E  2019-08-08             2019-07-22  2019-08-11
# 2          MDV/ trust 2019-12-30             2019-09-14  2019-09-29
# 4  WAL-MAR foundation 2019-11-25             2019-11-13  2019-11-28
# 5    THE  corporation 2019-12-04             2019-09-20  2019-10-04
#
#    total_open_amount baseline_create_date   delay
# 0           54273.28           2020-01-26  1 days
# 1           79656.60           2019-07-22 -3 days
# 2            2253.86           2019-09-14 92 days
# 4           33133.29           2019-11-13 -3 days
# 5           17558.41           2019-09-24 61 days

# %%
missing_valuesintrain = train.isnull().sum().sort_values(ascending=False)
missing_valuesintrain
# Out:
# name_customer             0
# clear_date                0
# document_create_date.1    0
# due_in_date               0
# total_open_amount         0
# baseline_create_date      0
# delay                     0
# dtype: int64

# %%
constant_features = get_constant_features(test)
constant_features.head()
# Out:
#        Desc         Var Value   Perc
# 0  Constant  clear_date   NaN  100.0
# 1  Constant      isOpen     1  100.0
# 2  Constant       delay   NaN  100.0

# %%
constant_features_list = constant_features.query("Desc=='Constant'")['Var'].to_list()
print(constant_features_list)
# Out:
# ['clear_date', 'isOpen', 'delay']

# %%
test.drop(columns = constant_features_list, inplace=True)
test.shape
# Out:
# (10000, 5)

# %%
test.head()
# Out:
#        name_customer document_create_date.1 due_in_date  total_open_amount  \
# 3           SYSC llc             2020-03-30  2020-04-10            2606.76
# 7            TARG us             2020-03-19  2020-04-03           11173.02
# 10               AM              2020-03-11  2020-03-26            3525.59
# 14        OK systems             2020-04-15  2020-04-30          121105.65
# 15  DECA corporation             2020-04-23  2020-04-26            3726.06
#
#    baseline_create_date
# 3            2020-03-31
# 7            2020-03-19
# 10           2020-03-11
# 14           2020-04-15
# 15           2020-04-16

# %%
missing_valuesintest = test.isnull().sum().sort_values(ascending=False)
missing_valuesintest
# Out:
# name_customer             0
# document_create_date.1    0
# due_in_date               0
# total_open_amount         0
# baseline_create_date      0
# dtype: int64
